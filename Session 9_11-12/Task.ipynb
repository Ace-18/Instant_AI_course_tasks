# %% [markdown]
# <h1>Task 1:</h1>

# %%
import re

text="abc^_^ 123` 435 "

# %%
pattern=re.compile("[\[-`]{3}")

matches=pattern.finditer(text)

for m in matches:
    print(m)
# Out:
# ...
# <re.Match object; span=(3, 6), match='^_^'>

# %%
# Out:
# '`'
